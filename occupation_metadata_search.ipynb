# %% [markdown]
# # quick stocktake of UK LLC occupation data

# %%
# packages
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import exc
from sqlalchemy.engine import URL
from IPython.display import display, Markdown

# %%
# DB connection info
def connect():
    '''
    Connect to the database with sql alchemy, system ODBC connection.
    Returns:
        engine (sqlalchemy object): engine for database operations
    '''
    connection_string = (
    r"DSN=LLC_DB"
    )
    connection_url = URL.create(
        "mssql+pyodbc",
        query={"odbc_connect": connection_string}
    )
    engine = create_engine(connection_url, isolation_level="AUTOCOMMIT")
    return engine

# %%
# connect to DB
cnxn = connect()
# query to pull all labs
sel_q = 'select * from DESCS.all_descriptions'
# read all labels
all_labs = pd.read_sql(sel_q, cnxn)

# %%
# occupation keywords define
occ_key = ['soc', 'soc2', 'sic', 'sic2', 'occupation', 'job']
# process list into format convenient fo search
occ_pat = ['\\b' + i + '\\b' for i in occ_key]
occ_pat = '|'.join(occ_pat)

# %%
# search
all_labs['occ_flag'] = all_labs['variable_label'].str.contains(occ_pat, case = False)
# filter the matches
occ_labs = all_labs.loc[all_labs['occ_flag'] == True]

# %%
# remove duplicate versions
occ_labs['table_name1'] = occ_labs['table_name'].str.split('_v000').str[0]
# drop unreq vars
occ_labs = occ_labs.drop(columns = ['avail_from_dt', 'table_name', 'occ_flag'], axis = 1)
# rename 
occ_labs = occ_labs.rename(columns = {'table_name1' : 'table_name',
                                     'TABLE_SCHEMA' : 'data_source'})
# remove dups
occ_labs = occ_labs.drop_duplicates()
# sort
occ_labs = occ_labs.sort_values(by = ['data_source', 'table_name', 'variable_name'])
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# group by study
study_group = occ_labs.groupby(by = 'data_source').size().reset_index(name = 'variable_count')
# display the dataframe
print(study_group.to_markdown(index=False, tablefmt="fancy_grid"))
# Out:
# ╒════════════════╤══════════════════╕
# │ data_source    │   variable_count │
# ╞════════════════╪══════════════════╡
# │ ALSPAC         │               16 │
# ├────────────────┼──────────────────┤
# │ BCS70          │              422 │
# ├────────────────┼──────────────────┤
# │ BIB            │               26 │
# ├────────────────┼──────────────────┤
# │ ELSA           │              145 │
# ├────────────────┼──────────────────┤
# │ EPICN          │                9 │
# ├────────────────┼──────────────────┤
# │ EXCEED         │                9 │
# ├────────────────┼──────────────────┤
# │ FENLAND        │               12 │
# ├────────────────┼──────────────────┤
# │ GENSCOT        │               16 │
# ├────────────────┼──────────────────┤
# │ GLAD           │                1 │
# ├────────────────┼──────────────────┤
# │ MCS            │              706 │
# ├────────────────┼──────────────────┤
# │ NCDS58         │             1416 │
# ├────────────────┼──────────────────┤
# │ NEXTSTEP       │              474 │
# ├────────────────┼──────────────────┤
# │ NICOLA         │               23 │
# ├────────────────┼──────────────────┤
# │ NIHRBIO_COPING │                1 │
# ├────────────────┼──────────────────┤
# │ NSHD46         │               23 │
# ├────────────────┼──────────────────┤
# │ SABRE          │               27 │
# ├────────────────┼──────────────────┤
# │ TWINSUK        │               23 │
# ├────────────────┼──────────────────┤
# │ UKHLS          │             2432 │
# ├────────────────┼──────────────────┤
# │ nhsd           │                9 │
# ╘════════════════╧══════════════════╛

# %% [markdown]
# **Table 1** Number of variables per **data source** with match on occupation keywords

# %%
# group by study + table_name
table_group = occ_labs.groupby(by = ['data_source', 'table_name']).size().reset_index(name = 'variable_count')
# display the dataframe
print(table_group.to_markdown(index=False, tablefmt="fancy_grid"))
# Out:
# ╒════════════════╤══════════════════════════════╤══════════════════╕
# │ data_source    │ table_name                   │   variable_count │
# ╞════════════════╪══════════════════════════════╪══════════════════╡
# │ ALSPAC         │ custom_occupationm           │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ALSPAC         │ custom_occupationy           │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ALSPAC         │ wave0m                       │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ALSPAC         │ wave0y                       │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ALSPAC         │ wave1m                       │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ALSPAC         │ wave1y                       │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ALSPAC         │ wave2m                       │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ALSPAC         │ wave2y                       │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ALSPAC         │ wave3m                       │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ALSPAC         │ wave3y                       │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ALSPAC         │ wave4m                       │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ALSPAC         │ wave4y                       │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ALSPAC         │ wave5m                       │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ALSPAC         │ wave5y                       │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ALSPAC         │ wave6m                       │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ALSPAC         │ wave6y                       │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BCS70          │ COVID_w1                     │                3 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BCS70          │ COVID_w2                     │               11 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BCS70          │ COVID_w3                     │               43 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BCS70          │ basic_demographic            │                3 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BCS70          │ bcs10                        │               28 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BCS70          │ bcs10_employment             │                4 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BCS70          │ bcs2                         │                6 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BCS70          │ bcs3                         │               17 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BCS70          │ bcs4                         │               68 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BCS70          │ bcs5                         │               37 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BCS70          │ bcs6                         │               45 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BCS70          │ bcs7                         │               29 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BCS70          │ bcs7_derived_follow_up       │               29 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BCS70          │ bcs8                         │               22 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BCS70          │ bcs9                         │               74 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BCS70          │ bcs9_employment              │                3 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BIB            │ CV19adult_P1                 │                2 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BIB            │ CV19adult_P3                 │                7 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BIB            │ CV19adult_P3a                │                7 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BIB            │ CV_W1                        │                2 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BIB            │ CV_W2                        │                5 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ BIB            │ SOCIODEMO                    │                3 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ELSA           │ elsa_covid_w1_eul            │                3 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ELSA           │ elsa_covid_w2_eul            │               18 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ELSA           │ wave_9_elsa_data_eul_dhdi    │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ELSA           │ wave_9_elsa_data_eul_ho1     │                5 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ELSA           │ wave_9_elsa_data_eul_spsc    │                5 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ELSA           │ wave_9_elsa_data_eul_wp      │              111 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ ELSA           │ wave_9_ifs_derived_variables │                2 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ EPICN          │ FU1                          │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ EPICN          │ FU2                          │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ EPICN          │ FU3                          │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ EPICN          │ FU4                          │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ EPICN          │ FU5                          │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ EPICN          │ FU7                          │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ EPICN          │ HLEQ1                        │                2 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ EPICN          │ HLQ                          │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ EXCEED         │ DemographicCore              │                2 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ EXCEED         │ covid19_q2                   │                4 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ EXCEED         │ covid19survey                │                2 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ EXCEED         │ occupation                   │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ FENLAND        │ P1                           │               12 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ GENSCOT        │ COVIDLIFE1                   │                5 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ GENSCOT        │ COVIDLIFE2                   │                4 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ GENSCOT        │ COVIDLIFE3                   │                4 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ GENSCOT        │ OCCUPATION                   │                3 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ GLAD           │ FILE2                        │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ COVID_CM_w1                  │                3 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ COVID_CM_w2                  │               11 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ COVID_CM_w3                  │               43 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ COVID_parent_w1              │                3 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ COVID_parent_w2              │               11 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ COVID_parent_w3              │               43 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ COVID_w1                     │                3 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ COVID_w2                     │               11 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ COVID_w3                     │               43 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ MCS_basic_demographic_cm     │                2 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ basic_demographic_cm         │                2 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ basic_demographic_parent     │                5 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs1_parent_derived          │                4 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs1_parent_interview        │               26 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs1_proxy_partner_interview │                7 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs2_parent_interview        │               79 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs2_proxy_partner_interview │                6 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs3_parent_derived          │                8 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs3_proxy_partner_interview │                8 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs4_cm_aspirations          │               16 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs4_parent_derived          │                8 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs4_parent_interview        │               70 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs4_proxy_partner_interview │               11 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs5_cm_interview            │               15 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs5_parent_cm_interview     │                2 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs5_parent_derived          │                5 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs5_parent_interview        │               52 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs5_proxy_partner_interview │               11 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs6_cm_interview            │               13 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs6_parent_cm_interview     │                2 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs6_parent_derived          │                5 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs6_parent_interview        │               46 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs6_proxy_partner_interview │                7 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs7_cm_interview            │               49 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs7_parent_cm_interview     │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ MCS            │ mcs7_parent_interview        │               75 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NCDS58         │ COVID_w1                     │                3 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NCDS58         │ COVID_w2                     │               11 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NCDS58         │ COVID_w3                     │               43 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NCDS58         │ basic_demographic            │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NCDS58         │ ncds0123                     │               51 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NCDS58         │ ncds4                        │              203 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NCDS58         │ ncds5                        │              521 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NCDS58         │ ncds5_partner                │              348 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NCDS58         │ ncds6                        │               45 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NCDS58         │ ncds6_biomedical             │               14 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NCDS58         │ ncds7                        │               25 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NCDS58         │ ncds8                        │              111 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NCDS58         │ ncds9                        │               35 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NCDS58         │ ncds9_employment             │                5 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ COVID_w1                     │                3 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ COVID_w2                     │               11 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ COVID_w3                     │               43 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ basic_demographic_data       │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ ns1                          │               14 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ ns1_family_background        │               11 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ ns1_parental_attitudes       │                2 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ ns2                          │               14 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ ns2_family_background        │               28 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ ns2_parental_attitudes       │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ ns3                          │               13 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ ns3_family_background        │                4 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ ns3_parental_attitudes       │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ ns4                          │               29 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ ns4_family_background        │               64 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ ns4_parental_attitudes       │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ ns5                          │               42 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ ns5_family_background        │                4 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ ns6                          │               68 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ ns7                          │               82 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NEXTSTEP       │ ns8                          │               38 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NICOLA         │ Covid_19Questionnaire        │                2 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NICOLA         │ Wave1CAPI                    │               18 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NICOLA         │ Wave1SCQ                     │                3 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NIHRBIO_COPING │ Bioresource                  │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NSHD46         │ COVIDW1WEBPOSTAL             │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NSHD46         │ COVIDW2WEBPOSTAL             │               13 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NSHD46         │ COVIDW3WEB                   │                8 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ NSHD46         │ SOCIODEMOGRAPHICS            │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ SABRE          │ COVID_WAVE2No                │                9 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ SABRE          │ COVID_WAVE2YES               │                4 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ SABRE          │ COVID_WAVE3                  │                9 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ SABRE          │ Covidwave1                   │                5 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ TWINSUK        │ COPE1                        │                6 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ TWINSUK        │ COPE2                        │                6 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ TWINSUK        │ COPE3                        │                4 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ TWINSUK        │ COPE4                        │                2 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ TWINSUK        │ COPE5                        │                3 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ TWINSUK        │ COPE6                        │                2 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ a_indresp                    │               76 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ b_indresp                    │              179 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ c_indresp                    │              160 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ ca_indresp_w                 │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ cb_indresp_w                 │                8 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ cc_indresp_w                 │               85 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ cd_indresp_w                 │                6 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ ce_indresp_w                 │               85 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ cf_indresp_w                 │                7 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ cg_indresp_w                 │               90 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ ch_indresp_w                 │               16 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ ci_indresp_w                 │               94 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ d_indresp                    │              167 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ e_indresp                    │              147 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ f_indresp                    │              190 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ g_indresp                    │              163 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ h_indresp                    │              198 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ i_indresp                    │              201 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ j_indresp                    │              186 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ k_indresp                    │              170 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ l_indresp                    │              197 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ xbaseline                    │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ UKHLS          │ xsample                      │                5 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ nhsd           │ CSDS_care_activities         │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ nhsd           │ CSDS_group_sessions          │                1 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ nhsd           │ MHSDS_MHS901StaffDetails     │                2 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ nhsd           │ MORTALITY                    │                3 │
# ├────────────────┼──────────────────────────────┼──────────────────┤
# │ nhsd           │ NPEX                         │                2 │
# ╘════════════════╧══════════════════════════════╧══════════════════╛

# %% [markdown]
# **Table 2** Number of variables per **dataset** with match on occupation keywords

# %%
# save out the full dataset
# occ_labs.to_csv('S:/UKLLC - UKLLC Databank/misc/occupation_data/stocktake.csv', index = False)
